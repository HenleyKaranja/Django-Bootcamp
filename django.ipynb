# %%
print('hello world')
# Out:
# hello world

# %%
def addTwoNumber():
    num1 = int(input("Enter first number: "))
    num2 = int(input("Enter second number: "))
    print(f"The sum of {num1} and {num2} is {num1+num2}")

addTwoNumber()
# Out:
# Enter first number:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 6
#       3     num2 = int(print("Enter second number: "))
#       4     print(f"The sum of {num1} and {num2} is {num1+num2}")
# ----> 6 addTwoNumber()
#
# Cell In[2], line 2, in addTwoNumber()
#       1 def addTwoNumber():
# ----> 2     num1 = int(print("Enter first number: "))
#       3     num2 = int(print("Enter second number: "))
#       4     print(f"The sum of {num1} and {num2} is {num1+num2}")
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
